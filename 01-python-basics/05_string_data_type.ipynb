# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/acmarpu/images/main/Python/05_string_type.png)

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# ### 🧵 3. String Data Type (Immutable)
# ----------------------------------------------------------------------------------------------
#
# #### 1. What is a String?
#
# * In Python, strings are an essential data type used to represent textual data.
# * Definition: A string is a sequence of characters enclosed in single quotes (' '), double quotes (" "), or triple quotes (''' ''' / """ """).
#     - Example: 'hello', "python", """world"""
# * String Methods: Python provides many built-in methods to manipulate strings.
#     - Examples: .replace(), .split(), .lower(), .upper(), .strip(), etc.
# * String Immutability: Strings are **immutable**, meaning once created, they cannot be modified.
#     - Operations like concatenation or .replace() return a new string instead of changing the original one.
# * String supports to Indexing
#
# * String format
#     - f-string (Python 3.6+): f'hello {name}
#     - str.foramt(): "Hello{}".format(name)
#     - % opetator: "Hello %s" % name

# %% [markdown]
# <br><br>

# %% [markdown]
# #### Creating String

# %%
my_string = "Hello, Apple!"
print("output of string value:", my_string)
print("output of string type:", type(my_string))
# Out:
# output of string value: Hello, Apple!
# output of string type: <class 'str'>

# %%
course_id = 1016
course_name = "python"

print(f"my course_id is {course_id} and my course name is {course_name}")

# Format method
print("Format method - my course_id is {} and my course name is {}".format(course_id, course_name))
# Out:
# my course_id is 1016 and my course name is python
# Format method - my course_id is 1016 and my course name is python

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String Indexing and Slicing
#
# * Indexing means accessing characters in a string using position numbers.
# * String indices start at 0 (for the first character).
#
#
#
# |Positive Indexing   | 0 | 1 | 2 | 3 | 4 | 5 |6  |7  |
# |--------------------|---|---|---|---|---|---|---|---|
# |                    | W | E | L |   | C | O | M | E |
# |--------------------|---|---|---|---|---|---|---|---|
# |Negative indexing   |-8 |-7 |-6 |-5 |-4 |-3 |-2 |-1 |

# %% [markdown]
# <br><br>

# %% [markdown]
# * **Indexing Examples**

# %%
my_string = "Hello, Apple!"
print("first character of string:", my_string[0])
print("seventh character of string:", my_string[6]) # 6th character of string is empty space is also a character in string. So, it will print space as output.

print("last character of string negative index:", my_string[-1])
print("last to seventh character of string negative index:", my_string[-7])
# Out:
# first character of string: H
# seventh character of string:
# last character of string negative index: !
# last to seventh character of string negative index:

# %% [markdown]
# <br><br>

# %% [markdown]
# * **Slicing**

# %% [markdown]
# * is used to extract a portion (substring) of a string.
# * The syntax for slicing is
#     - string[start:end]
#
# * *start* → Starting index (inclusive).
# * *end* → Ending index (exclusive), meaning the character at the end index is not included.

# %%
str = "Python"

print(str[0:2])   # Py
print(str[2:5])   # tho
print(str[:4])    # Pyth
print(str[3:6])   # hon
print(str[:6])    # Python
# Out:
# Py
# tho
# Pyth
# hon
# Python

# %% [markdown]
# <br><br>

# %% [markdown]
# * Reverse a String Without Using the `reverse()` Function
# * We can reverse a string using **slicing** with a **step value of `-1`**.
# * A step value of `-1` tells Python to traverse the string **from the end to the beginning**.

# %%
str = "Python"
print("output of reverse string:", str[::-1])

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String Concatenation and String Multiplication
# * Concatenation → The process of joining two or more strings using the + operator.
# * Multiplication → Used to repeat a string multiple times using the * operator.

# %%
str1 = "red"
str2 = "apple"

print("Concatenated string:", str1 + " " + str2)
print("Concatenated string using format method:", "{} {}".format(str1, str2))
print("Concatenated string:", str1 + "" + str2)
print(str1 * 3)
print((str1 + " " + str2 + " " ) * 3)
# Out:
# Concatenated string: red apple
# Concatenated string using format method: red apple
# Concatenated string: redapple
# redredred
# red apple red apple red apple

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String Split and Max Split
# * The split() method in Python divides a string into a list based on a specified separator.
# * separator → The delimiter to split the string (default: whitespace).
# * maxsplit → (optional): The maximum number of splits. Remaining string is returned as the last element.

# %%
string = "code4python"
print("Original string:", string)
print("String after split:", string.split())
print("String after split on '4':", string.split("4"))
print("String after max split on '4' with maxsplit=1:", string.split("4", 1))
# Out:
# Original string: code4python
# String after split: ['code4python']
# String after split on '4': ['code', 'python']
# String after max split on '4' with maxsplit=1: ['code', 'python']

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String count() Method
# * The count() method returns the number of occurrences of a specified substring within a given string.

# %%
str1 = "Python is very Easy and Anyone can learn"
print(str1)
print(str1.count(""))
print(str1.count('is'))
s2 = str1.count("a")
print(s2)
# Out:
# Python is very Easy and Anyone can learn
# 41
# 1
# 4

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String replace() Method
# * The replace() method returns a new string where all occurrences of a specified substring are replaced with another substring.

# %%
str1 = "python is very easy to learn"
print(str1.replace("easy", "hard"))
# Out:
# python is very hard to learn

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String Upper() and Lower(), title() Methods
# * These methods convert the case of characters in a string.

# %%
str1 = "python is very easy and Anyone can learn"
print("Upper case str1:", str1.upper())

str2 = str1.upper()
print("Upper case str2:", str2)

print("Lower case str1:", str2.lower())

str3 = str1.title()
print("Title Method str1:", str3.title())
# Out:
# Upper case str1: PYTHON IS VERY EASY AND ANYONE CAN LEARN
# Upper case str2: PYTHON IS VERY EASY AND ANYONE CAN LEARN
# Lower case str1: python is very easy and anyone can learn
# Title Method str1: Python Is Very Easy And Anyone Can Learn

# %% [markdown]
# <br><br>

# %% [markdown]
# #### Capitalize() Method
# * The capitalize() method returns a new string where the first character is converted to uppercase, and the rest of the string is converted to lowercase.

# %%
str4 = str1.capitalize()
print("Capitalize Method str1:", str4.capitalize())
# Out:
# Capitalize Method str1: Python is very easy and anyone can learn

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String swapcase() Method
# * The swapcase() method returns a new string where uppercase letters become lowercase and lowercase letters become uppercase

# %%
str1 = "Python Is Very Easy To Learn."
str2 = str1.swapcase()
print(str2)
# Out:
# pYTHON iS vERY eASY tO lEARN.

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String Reverse
# * There is no direct reverse() method for strings since they are immutable.
# * We can reverse using slicing [::-1].

# %%
str1 = "python"
print(str1[::-1])
# Out:
# nohtyp

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String Immutability
# * Strings in Python cannot be changed after creation.
# * Any operation that seems to modify a string actually creates a new string.

# %%
str1 = "python"
print(id(str1))
s = s + "language"
print(s)
print(id(s))

# %% [markdown]
# <br><br>

# %% [markdown]
# #### String Sort
# * You can split a string into words and then sort them alphabetically.

# %%
s = "python is very easy"
str1 = s.split()
print(str1)
str1.sort()
print(str1)
str1.sort(reverse=True)
print(str1)
# Out:
# ['python', 'is', 'very', 'easy']
# ['easy', 'is', 'python', 'very']
# ['very', 'python', 'is', 'easy']

# %% [markdown]
# <br><br>

# %% [markdown]
# #### join() Function
# * The join() method combines elements of an iterable (like a string or list) into a single string.

# %%
str1 = ["Python", "is", "awesome"]
print("Joined string:", " ".join(str1))
print("str1 after join method:", '|'.join(str1))

str2 = ''.join(reversed(str1))
print("Reversed and joined string:", str2)

str3 = ','.join(str1)
print("Joined with comma:", str3)
# Out:
# Joined string: Python is awesome
# str1 after join method: Python|is|awesome
# Reversed and joined string: awesomeisPython
# Joined with comma: Python,is,awesome

# %% [markdown]
# <br><br>

# %% [markdown]
# #### strip(), lstrip(), and rstrip()
# * These methods remove whitespace or specified characters from a string.
# * They return a copy of the string with leading and/or trailing characters removed

# %%
str1 = "  Python   "
print("Removed the spaces:", str1.strip())
print("Removes spaces on the right:", str1.rstrip())
print("Removes spaces on the left:", str1.lstrip())
# Out:
# Removed the spaces: Python
# Removes spaces on the right:   Python
# Removes spaces on the left: Python

# %% [markdown]
# <br><br>

# %% [markdown]
# #### len()
# Returns the length of the string.

# %%
s = "python"
print(len(s))
# Out:
# 6

# %% [markdown]
# <br><br>

# %% [markdown]
# #### find()
# * Returns the index of the first occurrence of a substring.
# * Returns -1 if not found.

# %%
s = "python"
print("find b in s value:", s.find("b"))
print("find b in s value:", s.find("t"))
# Out:
# find b in s value: -1
# find b in s value: 2

# %% [markdown]
# <br><br>

# %% [markdown]
# #### max() and min()
# * Return the highest and lowest alphabetical characters.

# %%
s = "python"
print(max(s))
print(min(s))
# Out:
# y
# h

# %% [markdown]
# <br><br>

# %% [markdown]
# #### index()
# * Returns the index of the first occurrence of a substring.
# * Raises an error if the substring is not found.

# %%
s = "python"
print("Index of 't':", s.index("t"))
print("Index of 'th':", s.index("th"))
# Out:
# Index of 't': 2
# Index of 'th': 2

# %% [markdown]
# <br><br>

# %% [markdown]
# #### rindex()
# * Returns the highest index of the substring.

# %%
s = "python is very easy"
print(s.rindex("y"))
# Out:
# 18

# %% [markdown]
# <br><br>

# %% [markdown]
# #### partition()
# * Splits the string at the first occurrence of the separator and returns a tuple.

# %%
s = "python is very easy and it is opp and it is interpreted is"
print(s.split(" "))
print(s.partition("is"))
# Out:
# ['python', 'is', 'very', 'easy', 'and', 'it', 'is', 'opp', 'and', 'it', 'is', 'interpreted', 'is']
# ('python ', 'is', ' very easy and it is opp and it is interpreted is')

# %% [markdown]
# <br><br>

# %% [markdown]
# #### startswith()
# * Returns True if the string starts with the given prefix.

# %%
str1 = "python is easy"
print("Starts with 'python':", str1.startswith("python"))
print("Starts with 'is':", str1.startswith("is"))
# Out:
# Starts with 'python': True
# Starts with 'is': False

# %% [markdown]
# <br><br>

# %% [markdown]
# #### endswith()
# * Returns True if the string ends with the given suffix.

# %%
s = "python is easy"
print(s.endswith("easy"))
print(s.endswith("is"))
# Out:
# True
# False

# %% [markdown]
# <br><br>

# %% [markdown]
# #### isdigit()
# * Returns True if all characters in the string are digits

# %%
s = "12345"
print(s.isdigit())
# Out:
# True

# %% [markdown]
# <br><br>

# %% [markdown]
# #### isalpha()
# * Returns True if all characters in the string are alphabets.

# %%
s = "Python"
print(s.isalpha())
# Out:
# True

# %% [markdown]
# <br><br>

# %% [markdown]
# #### isalnum()
# * Returns True if all characters are alphanumeric (letters and digits only).

# %%
s = "Python123"
print(s.isalnum())

# Reverse Each Word in a String

s = "python is very easy"
str1 = s.split(" ")
print(str1)


for i in str1:
      print(i[::-1], end=" ")
# Out:
# True
# ['python', 'is', 'very', 'easy']
# nohtyp si yrev ysae

# %% [markdown]
# <br><br>

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# ##### String Data Type Completed
#
# 📖 **Next Topic:**
# 👉 [List Data Type](06_list_data_type.ipynb)
# ----------------------------------------------------------------------------------------------

# %%
#------------------------------------------------------------
# Practic Question 1
#------------------------------------------------------------

# From a log message string "ERROR: Pod crashed at 10:00, slice to get only "ERROR"

log_message = "2025-06-01 10:00:00 ERROR: Pod crashed"

# Slice the log message to get only "ERROR"
error_message = log_message[20:25]  # Extract substring from index 20 to 25 (inclusive)

print("\n sliced error message:", error_message)

print(type(error_message))
# Out:
#  sliced error message: ERROR
# <class 'str'>

# %%
#------------------------------------------------------------
# Practic Question 2
#------------------------------------------------------------

# F string practic

course_id = 1001
course_name = "python"

print(f"my course id is {course_id} and my course name is {course_name}")

# Format method practice 
print("my course id is {} and my course name is {}". format(course_id, course_name))

# % formatting practice
print("my Course ID is %d and my course name is %s" % (course_id, course_name) )
# Out:
# my course id is 1001 and my course name is python
# my course id is 1001 and my course name is python
# my Course ID is 1001 and my course name is python

# %%
#------------------------------------------------------------
# Practic Question 3
#------------------------------------------------------------

str1 = "python is very easy and Anyone can learn"
print("Upper case str1:", str1.upper())

str2 = str1.upper()
print("Upper case str2:", str2)

str3 = str1.lower()
print("Lower case str3:", str3)

str4 = str1.title()
print("Title str4:", str4)

str5 = str1.capitalize()
print("capitalize str5:", str5)
# Out:
# Upper case str1: PYTHON IS VERY EASY AND ANYONE CAN LEARN
# Upper case str2: PYTHON IS VERY EASY AND ANYONE CAN LEARN
# Lower case str3: python is very easy and anyone can learn
# Title str4: Python Is Very Easy And Anyone Can Learn
# capitalize str5: Python is very easy and anyone can learn

# %%
#------------------------------------------------------------
# Practic Question 4
#------------------------------------------------------------

#  Removed the spaces: Python

str1 = "  Python   "                 # Original string with spaces
print("Removed the spaces:", str1.strip())      # Output: Removed the spaces: Python

# %%
# Join method practice
str1 = ["Python", "is", "awesome"]
print("Joined string:", " ".join(str1))  # Output: Joined string: Python is awesome
print("str1 after join method:", '|'.join(str1))  # Output: str1 after join method: Python|is|awesome
str2 = ''.join(reversed(str1))
print("Reversed and joined string:", str2)  # Output: Reversed and joined string: awesomeisPython
str3 = ','.join(str1)
print("Joined with comma:", str3)  # Output: Joined with comma: Python,is,awesome
# Out:
# Joined string: Python is awesome
# str1 after join method: Python|is|awesome
# Reversed and joined string: awesomeisPython
# Joined with comma: Python,is,awesome
