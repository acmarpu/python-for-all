# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/acmarpu/images/main/Python/20_api.png)

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# ### API
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# #### HTTP Methods (Operations)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/acmarpu/images/main/Python/20_3_api.png)

# %% [markdown]
# #### API Request Structure

# %% [markdown]
# * https://api.example.com/users?id=10&role=admin
#
# ![alt text](https://raw.githubusercontent.com/acmarpu/images/main/Python/20_1_api.jpg)

# %% [markdown]
# |          **Headers**               |    **Request Body(JSON)**     | **Parameters**    |
# |------------------------------------|-------------------------------|-------------------|
# | * Authorization: Bearer Token      |{ "name": "Ashoka",            | * id = 10         |
# | * Content-Type: Application/json   |  "emai": "ashoka@gmail.com",  | * role = admin    |
# | * Accept: Application/json         |  "role: "Student",            | * page = 1        |
# | * User- Agent: Chrome/124.0        |  "city: "Hyderabad"           | * limit = 20      |
# |                                    | }                             |                   |
#
# * Whenever utilizing API
# 1. URL (domain name and endpoint)
# 2. Header
# 3. Payloud
# 4. Parameters or filters

# %% [markdown]
# #### HTTP Status Codes

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/acmarpu/images/main/Python/20_2_api.png)
