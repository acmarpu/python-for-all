# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/acmarpu/images/main/Python/18_exception_handling.png)

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# ### File Handling & Config Automation
# ----------------------------------------------------------------------------------------------
#
# * Read/Write files
# * JSON/YAML Configs
# * Safe file handling
#
# * Read/write files
# with
#
# * Use config files
#
# * Use JSON FIles
