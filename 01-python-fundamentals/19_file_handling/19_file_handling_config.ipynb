# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/acmarpu/images/main/Python/19_file_hand.png)

# %% [markdown]
# ----------------------------------------------------------------------------------------------
# ### 📁 File Handling & Config Automation
# ----------------------------------------------------------------------------------------------
# - **Read/Write Files** – Read data from files and write data to files using Python.
# - **JSON Files** – Store and read structured data using the JSON format.
# - **YAML Configs** – Store application or automation configuration in YAML files.
# - **Safe File Handling** – Handle files safely using proper paths, permissions, and exception handling.
# - **Configuration Files** – Keep configuration settings separate from the main Python code.

# %% [markdown]
# ##### Syntax
# open('filename', mode) # mode(r, a, w, x, t,b)  could be to read, write, update
#
# * "r" - Read - Default value. Opens a file for reading, it returns an error if the file does not exist
# * "a" - Append - Opens a file for appending, creates the file if it does not exist
# * "w" - Write - Opens a file for writing, creates the file if it does not exist
# * "x" - Create - Creates the specified file, returns an error if the file exists
# * "t" - Text - Default value. Text mode
# * "b" - Binary - Binary mode (e.g. images)

# %%
# Deleting Files 
import os
os.remove('./files/simple.txt')
